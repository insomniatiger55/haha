# %%
import configparser

# %%
config=configparser.ConfigParser()

# %%
config.read('sample.ini')
# Out:
# ['sample.ini']

# %%
for x in config.items():
    print(x)
# Out:
# ('DEFAULT', <Section: DEFAULT>)
# ('Settings', <Section: Settings>)
# ('FTP', <Section: FTP>)
# ('FTPS', <Section: FTPS>)
# ('TFTP', <Section: TFTP>)
# ('HTTP', <Section: HTTP>)
# ('HTTPS', <Section: HTTPS>)
# ('BACKUP_SERVERS', <Section: BACKUP_SERVERS>)
# ('SNMP', <Section: SNMP>)

# %%
config.sections()
# Out:
# ['Settings', 'FTP', 'FTPS', 'TFTP', 'HTTP', 'HTTPS', 'BACKUP_SERVERS', 'SNMP']

# %%
# Out:
# <Section: Settings>

# %%
for k,v in config.items('Settings'):
    print(' {} = {}'.format(k,v))
# Out:
#  detailedlog = 1
#  runstatus = 1
#  statusport = 6090
#  statusrefresh = 10
#  archive = 1
#  logfile = /opt/ecs/mvuser/MV_IPTel/log/MV_IPTel.log
#  version = 0.9 Build 4 Created July 11 2004 14:00
#  servername = Unknown

# %%
config['Settings']['logfile']
# Out:
# '/opt/ecs/mvuser/MV_IPTel/log/MV_IPTel.log'

# %%
for sect in config.sections():  
    print('Section:', sect)
    for k,v in config.items(sect):
        print(' {} = {}'.format(k,v))
# Out:
# Section: Settings
#  detailedlog = 1
#  runstatus = 1
#  statusport = 6090
#  statusrefresh = 10
#  archive = 1
#  logfile = /opt/ecs/mvuser/MV_IPTel/log/MV_IPTel.log
#  version = 0.9 Build 4 Created July 11 2004 14:00
#  servername = Unknown
# Section: FTP
#  runftp = 1
#  ftpport = 21
#  ftpdataport = 20
#  ftpdir = /opt/ecs/mvuser/MV_IPTel/data/FTPdata
#  ftp_timeout = 5
#  enablesu = 1
#  suusername = mvuser
#  supassword = Avaya
# Section: FTPS
#  runftps = 0
#  ftpport = 990
#  ftpdataport = 889
# Section: TFTP
#  runtrivialftp = 1
#  trivialftpport = 69
#  tftpdir = /opt/ecs/mvuser/MV_IPTel/data/TFTPdata
# Section: HTTP
#  runhttp = 1
#  httpport = 81
#  httpdir = /opt/ecs/mvuser/MV_IPTel/data/HTTPdata
# Section: HTTPS
#  runhttps = 0
#  httpsport = 411
#  httpsdir = /opt/ecs/mvuser/MV_IPTel/data/HTTPSdata
#  certfile = /opt/ecs/mvuser/MV_IPTel/certs/IPTelcert.pem
#  keyfile = /opt/ecs/mvuser/MV_IPTel/certs/IPTelkey.pem
#  clientauth = 0
#  iptel = 0
#  sslv2 = 0
#  sslv3 = 0
#  tlsv1 = 1
#  useproxy = 0
#  proxyaddr = simon.avaya.com
#  proxyport = 9000
# Section: BACKUP_SERVERS
#  fileserver = 0
#  requestupdates = 0
#  requestbackup = 0
#  useprimarysvr = 0
#  primaryip = 192.168.0.13
#  usesecondarysvr = 0
#  secondaryip = 192.168.0.10
#   = hour, 3=day, 4 =month
#  updateinterval = 2
#  customftp = 1
#  customftpdir = home/mvuser/backup
#  customftpuname = tom
#  customftppwd = jerry
#  cdrbackup = 0
#  bcmsbackup = 0
#  retaindays = 7.0
# Section: SNMP
#  usesnmp = 1

# %%
'BACKUP_SERVERS' in config
# Out:
# True

# %%
w=pw.encode()
